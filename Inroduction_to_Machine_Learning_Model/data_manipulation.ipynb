# %% [markdown]
# $Data-Manipulation$

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#axis=0 is the deafult. that means rows if we want to drop columns we need to specift axis=1
df.drop(labels = ['pclass'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#    survived     sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0    male  22.0      1      0   7.2500        S  Third    man
# 1         1  female  38.0      1      0  71.2833        C  First  woman
# 2         1  female  26.0      0      0   7.9250        S  Third  woman
# 3         1  female  35.0      1      0  53.1000        S  First  woman
# 4         0    male  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
df.drop(df[df['sex'] != 'male'].index)
# Out:
#      survived   sex   age  sibsp  parch     fare embarked   class    who  \
# 0           0  male  22.0      1      0   7.2500        S   Third    man
# 4           0  male  35.0      0      0   8.0500        S   Third    man
# 5           0  male   NaN      0      0   8.4583        Q   Third    man
# 6           0  male  54.0      0      0  51.8625        S   First    man
# 7           0  male   2.0      3      1  21.0750        S   Third  child
# ..        ...   ...   ...    ...    ...      ...      ...     ...    ...
# 883         0  male  28.0      0      0  10.5000        S  Second    man
# 884         0  male  25.0      0      0   7.0500        S   Third    man
# 886         0  male  27.0      0      0  13.0000        S  Second    man
# 889         1  male  26.0      0      0  30.0000        C   First    man
# 890         0  male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
#bilgileri aynı olan satırları silmek için.
df.drop_duplicates()
# Out:
#      survived     sex   age  sibsp  parch     fare embarked  class    who  \
# 0           0    male  22.0      1      0   7.2500        S  Third    man
# 1           1  female  38.0      1      0  71.2833        C  First  woman
# 2           1  female  26.0      0      0   7.9250        S  Third  woman
# 3           1  female  35.0      1      0  53.1000        S  First  woman
# 4           0    male  35.0      0      0   8.0500        S  Third    man
# ..        ...     ...   ...    ...    ...      ...      ...    ...    ...
# 885         0  female  39.0      0      5  29.1250        Q  Third  woman
# 887         1  female  19.0      0      0  30.0000        S  First  woman
# 888         0  female   NaN      1      2  23.4500        S  Third  woman
# 889         1    male  26.0      0      0  30.0000        C  First    man
# 890         0    male  32.0      0      0   7.7500        Q  Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
df.drop_duplicates(subset=['sex'])
# Out:
#    survived     sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0    male  22.0      1      0   7.2500        S  Third    man
# 1         1  female  38.0      1      0  71.2833        C  First  woman
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False

# %%
df.groupby(by=['sex']).count()
# Out:
#         survived  age  sibsp  parch  fare  embarked  class  who  adult_male  \
# sex
# female       314  261    314    314   314       312    314  314         314
# male         577  453    577    577   577       577    577  577         577
#
#         deck  embark_town  alive  alone
# sex
# female    97          312    314    314
# male     106          577    577    577

# %%
df.groupby(by=['sex', 'alive']).count()
# Out:
#               survived  age  sibsp  parch  fare  embarked  class  who  \
# sex    alive
# female no           81   64     81     81    81        81     81   81
#        yes         233  197    233    233   233       231    233  233
# male   no          468  360    468    468   468       468    468  468
#        yes         109   93    109    109   109       109    109  109
#
#               adult_male  deck  embark_town  alone
# sex    alive
# female no             81     6           81     81
#        yes           233    91          231    233
# male   no            468    61          468    468
#        yes           109    45          109    109

# %% [markdown]
# $--$

# %%
import pandas as pd
df2 = pd.read_csv('titanic2.csv')

# %%
for name in df2['Name'][:10]:
    print(name)
# Out:
# Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# Heikkinen, Miss. Laina
# Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Allen, Mr. William Henry
# Moran, Mr. James
# McCarthy, Mr. Timothy J
# Palsson, Master. Gosta Leonard
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Nasser, Mrs. Nicholas (Adele Achem)

# %%
def upperCase(x):
    return x.upper()


df2['Name'].apply(upperCase)
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
dataSet_1 = {
    'id' : [1,2,3,4,5],
    'ad' : ['Ahmet', 'Mehmet', 'Ali', 'Veli', 'Ayşe'],
    'soyad' : ['Yılmaz', 'Kaya', 'Şahin', 'Çelik', 'Kaya']
}

dataSet_2 = {
    'id' : [6,7,8,9,10],
    'ad' : ['John', 'Jack', 'Kate', 'Claire', 'Sawyer'],
    'soyad' : ['Shephard', 'Shephard', 'Austen', 'Littleton', 'Ford']
}

# %%
df_a = pd.DataFrame(dataSet_1)

# %%
df_b = pd.DataFrame(dataSet_2)

# %%
concat_df = pd.concat([df_a, df_b])

# %%
#pd.concat([df_a, df_b], axis=1)

# %%
concat_df
# Out:
#    id      ad      soyad
# 0   1   Ahmet     Yılmaz
# 1   2  Mehmet       Kaya
# 2   3     Ali      Şahin
# 3   4    Veli      Çelik
# 4   5    Ayşe       Kaya
# 0   6    John   Shephard
# 1   7    Jack   Shephard
# 2   8    Kate     Austen
# 3   9  Claire  Littleton
# 4  10  Sawyer       Ford

# %%
employees = {
    'employee_id' : [1,2,3,4],
    'name' : ['Greg', 'Wilson', 'Chase', 'Thirteen'],
}

sales = {
    'employee_id' : [3,4,5,6],
    'total_sales' : [23456, 2512, 2345, 1455]
}

# %%
employees_df = pd.DataFrame(employees)
sales_df = pd.DataFrame(sales)

# %%
pd.merge(employees_df, sales_df, on='employee_id', how='left')
# Out:
#    employee_id      name  total_sales
# 0            1      Greg          NaN
# 1            2    Wilson          NaN
# 2            3     Chase      23456.0
# 3            4  Thirteen       2512.0

# %%
pd.merge(employees_df, sales_df, on='employee_id', how='right')
# Out:
#    employee_id      name  total_sales
# 0            3     Chase        23456
# 1            4  Thirteen         2512
# 2            5       NaN         2345
# 3            6       NaN         1455

# %%
pd.merge(employees_df, sales_df, on='employee_id', how='outer')
# Out:
#    employee_id      name  total_sales
# 0            1      Greg          NaN
# 1            2    Wilson          NaN
# 2            3     Chase      23456.0
# 3            4  Thirteen       2512.0
# 4            5       NaN       2345.0
# 5            6       NaN       1455.0
